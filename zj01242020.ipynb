# %%
from scipy.integrate import odeint
import numpy as N

def f(y,t):
    return 9.81-(12.5/68.)*y

y0 = 0
a = 0
b = 12

t = N.arange(a,b,0.01)
y = odeint(f,y0,t)
import pylab
pylab.plot(t,y)
pylab.xlabel('t');pylab.ylabel('y(t)')
pylab.show()
